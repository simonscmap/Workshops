# %% [markdown]
# <!--NAVIGATION-->
# < [Catalog](Catalog.ipynb) | [Index](Index.ipynb) | [Datasets](Datasets.ipynb) >
#
# <a href="https://colab.research.google.com/github/simonscmap/pycmap/blob/master/docs/SearchCatalog.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/simonscmap/pycmap/master?filepath=docs%2FSearchCatalog.ipynb"><img align="right" src="https://mybinder.org/badge_logo.svg" alt="Open in Colab" title="Open and Execute in Binder"></a>

# %% [markdown]
# ## *search_catalog(keywords)*
#
#
# Returns a dataframe containing a subset of Simons CMAP catalog of variables.
#
# All variables at Simons CMAP catalog are annotated with a collection of semantically related keywords. This method takes the passed keywords and returns all of the variables annotated with similar keywords. The passed keywords should be separated by blank space. The search result is not sensitive to the order of keywords and is not case sensitive. The passed keywords can provide any 'hint' associated with the target variables. Below are a few examples:
#
# * the exact variable name (e.g. NO3), or its linguistic term (Nitrate)
# * methodology (model, satellite ...), instrument (CTD, seaflow), or disciplines (physics, biology ...)
# * the cruise official name (e.g. KOK1606), or unofficial cruise name (Falkor)
# * the name of data producer (e.g Penny Chisholm) or institution name (MIT)
#
# <br />If you searched for a variable with semantically-related-keywords and did not get the correct results, please let us know. We can update the keywords at any point.

# %% [markdown]
# > **Parameters:**
# >> **keywords: string**
# >>  <br />Search keywords separated by a blank space. The search result is not sensitive to the order of keywords and is not case sensitive.
#
#
# >**Returns:**
# >>  Pandas dataframe.

# %% [markdown]
# ### Example 1
# List of all measurements by University of Hawaii hosted by Simons CMAP.

# %%
#!pip install pycmap -q     #uncomment to install pycmap, if necessary

import pycmap

api = pycmap.API(token='19e91d80-ae64-12e9-8f77-f3e8f5c1f730')
api.search_catalog('University of Hawaii')
# Out:
#                        Variable                Table_Name  \
# 0                    Alkalinity          tblHOE_legacy_2A
# 1                 Bottle_Oxygen          tblHOE_legacy_2A
# 2                          Cast          tblHOE_legacy_2A
# 3                   Chlorophyll          tblHOE_legacy_2A
# 4             CTD_Chloropigment          tblHOE_legacy_2A
# ...                         ...                       ...
# 1317                        PAR  tblMESOSCOPEb_Wirewalker
# 1318  potential_density_anomaly  tblMESOSCOPEb_Wirewalker
# 1319         practical_salinity  tblMESOSCOPEb_Wirewalker
# 1320                   pressure  tblMESOSCOPEb_Wirewalker
# 1321                temperature  tblMESOSCOPEb_Wirewalker
#
#                                               Long_Name           Unit  \
# 0                                  Titration Alkalinity         ueq/kg
# 1                               Bottle Dissolved Oxygen        umol/kg
# 2                                           Cast Number              #
# 3                              Fluorometric Chlorophyll           ug/l
# 4                                     CTD Chloropigment           ug/l
# ...                                                 ...            ...
# 1317  Photosynthetically available radiation, downwa...  Âµmol m-2 s-1
# 1318                 Potential density anomaly wrt 0 db         kg m-3
# 1319                                 Practical salinity            NaN
# 1320                                           Pressure             db
# 1321                                        Temperature            Â°C
#
#              Make      Sensor Process_Level     Study_Domain  \
# 0     Observation     In-Situ   Reprocessed  Biogeochemistry
# 1     Observation     In-Situ   Reprocessed          Biology
# 2     Observation     In-Situ   Reprocessed    Uncategorized
# 3     Observation     In-Situ   Reprocessed  Biogeochemistry
# 4     Observation     In-Situ   Reprocessed          Physics
# ...           ...         ...           ...              ...
# 1317  Observation  Radiometer   Reprocessed    Uncategorized
# 1318  Observation         CTD   Reprocessed          Physics
# 1319  Observation         CTD   Reprocessed          Physics
# 1320  Observation         CTD   Reprocessed          Physics
# 1321  Observation         CTD   Reprocessed          Physics
#
#      Temporal_Resolution Spatial_Resolution  ...  \
# 0              Irregular          Irregular  ...
# 1              Irregular          Irregular  ...
# 2              Irregular          Irregular  ...
# 3              Irregular          Irregular  ...
# 4              Irregular          Irregular  ...
# ...                  ...                ...  ...
# 1317               1/6 s          Irregular  ...
# 1318               1/6 s          Irregular  ...
# 1319               1/6 s          Irregular  ...
# 1320               1/6 s          Irregular  ...
# 1321               1/6 s          Irregular  ...
#
#                                            Dataset_Name    Dataset_Short_Name  \
# 0     2015 Hawaii Ocean Experiment - Legacy 2A, Wate...  KM1513_HOE_Legacy_2A
# 1     2015 Hawaii Ocean Experiment - Legacy 2A, Wate...  KM1513_HOE_Legacy_2A
# 2     2015 Hawaii Ocean Experiment - Legacy 2A, Wate...  KM1513_HOE_Legacy_2A
# 3     2015 Hawaii Ocean Experiment - Legacy 2A, Wate...  KM1513_HOE_Legacy_2A
# 4     2015 Hawaii Ocean Experiment - Legacy 2A, Wate...  KM1513_HOE_Legacy_2A
# ...                                                 ...                   ...
# 1317                       Wirewalker_MESOSCOPEb_Level1      WW_MESOSCOPEb_L1
# 1318                       Wirewalker_MESOSCOPEb_Level1      WW_MESOSCOPEb_L1
# 1319                       Wirewalker_MESOSCOPEb_Level1      WW_MESOSCOPEb_L1
# 1320                       Wirewalker_MESOSCOPEb_Level1      WW_MESOSCOPEb_L1
# 1321                       Wirewalker_MESOSCOPEb_Level1      WW_MESOSCOPEb_L1
#
#                       Data_Source                  Distributor  \
# 0     University of Hawaii, Manoa  University of Hawaii, Manoa
# 1     University of Hawaii, Manoa  University of Hawaii, Manoa
# 2     University of Hawaii, Manoa  University of Hawaii, Manoa
# 3     University of Hawaii, Manoa  University of Hawaii, Manoa
# 4     University of Hawaii, Manoa  University of Hawaii, Manoa
# ...                           ...                          ...
# 1317  University of Hawaii, Manoa                          NaN
# 1318  University of Hawaii, Manoa                          NaN
# 1319  University of Hawaii, Manoa                          NaN
# 1320  University of Hawaii, Manoa                          NaN
# 1321  University of Hawaii, Manoa                          NaN
#
#                                     Dataset_Description  \
# 0     The objective of the cruise was to deploy and ...
# 1     The objective of the cruise was to deploy and ...
# 2     The objective of the cruise was to deploy and ...
# 3     The objective of the cruise was to deploy and ...
# 4     The objective of the cruise was to deploy and ...
# ...                                                 ...
# 1317  The Wirewalker is a  wave-powered drifting pro...
# 1318  The Wirewalker is a  wave-powered drifting pro...
# 1319  The Wirewalker is a  wave-powered drifting pro...
# 1320  The Wirewalker is a  wave-powered drifting pro...
# 1321  The Wirewalker is a  wave-powered drifting pro...
#
#                                         Acknowledgement  Dataset_ID    ID  \
# 0                                                   NaN         100  1994
# 1                                                   NaN         100  1992
# 2                                                   NaN         100  1984
# 3                                                   NaN         100  2005
# 4                                                   NaN         100  1989
# ...                                                 ...         ...   ...
# 1317  We thank the SCOPE operation team for data col...         256  3460
# 1318  We thank the SCOPE operation team for data col...         256  3456
# 1319  We thank the SCOPE operation team for data col...         256  3455
# 1320  We thank the SCOPE operation team for data col...         256  3451
# 1321  We thank the SCOPE operation team for data col...         256  3452
#
#       Visualize                                           Keywords
# 0           1.0  BioGeoChemistry, Core Data, cruise, Diel, Gran...
# 1           1.0  biology, Bottle Dissolved Oxygen, Core Data, c...
# 2           NaN  Cast Number, Core Data, cruise, Diel, HOE-Lega...
# 3           1.0  10-AU, BioGeoChemistry, Core Data, cruise, Die...
# 4           1.0  Core Data, cruise, CTD, CTD Oxygen, Diel, HOE-...
# ...         ...                                                ...
# 1317        1.0  autonomous, downward cosine irradiance, drifte...
# 1318        1.0  autonomous, drifter, in-situ, Karl, KM1709, La...
# 1319        1.0  autonomous, drifter, in-situ, Karl, KM1709, La...
# 1320        1.0  autonomous, drifter, in-situ, Karl, KM1709, La...
# 1321        1.0  autonomous, drifter, in-situ, Karl, KM1709, La...
#
# [1322 rows x 37 columns]

# %% [markdown]
# ### Example 2
# Returns a list of Nitrite measurements during the Falkor cruise, if exists.

# %%
#!pip install pycmap -q     #uncomment to install pycmap, if necessary

import pycmap

api = pycmap.API()
api.search_catalog('nitrite falkor')
# Out:
#   Variable      Table_Name             Long_Name     Unit         Make  \
# 0  NO3_NO2  tblFalkor_2018  Nitrate plus Nitrite  umol/kg  Observation
#
#     Sensor Process_Level     Study_Domain Temporal_Resolution  \
# 0  In-Situ   Reprocessed  Biogeochemistry           Irregular
#
#   Spatial_Resolution  ...                                 Dataset_Name  \
# 0          Irregular  ...  2018 SCOPE Falkor Cruise, Water Column Data
#
#   Dataset_Short_Name                  Data_Source  \
# 0        Falkor_2018  University of Hawaii, Manoa
#
#                    Distributor  \
# 0  University of Hawaii, Manoa
#
#                                  Dataset_Description  Acknowledgement  \
# 0  The 2018 SCOPE-Falkor Cruise was built on the ...              NaN
#
#    Dataset_ID    ID  Visualize  \
# 0          99  1404          1
#
#                                             Keywords
# 0  Autoanalyzer, Core Data, cruise, FK180310, Nit...
#
# [1 rows x 37 columns]

# %% [markdown]
# ### Example 3
# Returns a list of optical measurements during the Gradients 1 cruise (KOK1606), if exists.

# %%
#!pip install pycmap -q     #uncomment to install pycmap, if necessary

import pycmap

api = pycmap.API(token='<YOUR_API_KEY>')
api.search_catalog('optics KOK1606')

# %% [markdown]
# <img src="figures/sql.png" alt="SQL" align="left" width="40"/>
# <br/>
# ### SQL Statement
# Here is how to achieve the same results using a direct SQL statement. Please refere to [Query](Query.ipynb) for more information.

# %% [markdown]
# <code>EXEC uspSearchCatalog 'space-separated keywords'</code><br/><br/>
# **Example:**<br/>
# List of satellite Chlorophyll products:<br/><br/>
# <code>EXEC uspSearchCatalog 'chl satellite'</code><br/>
